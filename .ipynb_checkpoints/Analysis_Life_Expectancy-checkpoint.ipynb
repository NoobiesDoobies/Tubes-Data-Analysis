# %% [markdown]
# # Analisis Life Expectancy
# ## Kelompok 1
# |Nama|NIM|
# |:-:|:-:|
# |Muhammad Zamroni|16721038|
# |Billy Christianto|16721048|
# |Afifah Anugrayni|16721233|
# |Carlios Eryan|16721253|
#
#
# ## Dataset yang digunakan:
# Life Expectancy [(sumber)](https://www.kaggle.com/kumarajarshi/life-expectancy-who)
# > Format: CSV
# >
# > Ukuran file: 333 kB
# >
# > Dimensi: 2938 baris x 22 kolom
# >
# > Deskripsi: Proyek ini bergantung pada keakuratan data. Penyimpanan data Observatorium Kesehatan Global (GHO) di bawah Organisasi Kesehatan Dunia (WHO) melacak status kesehatan serta banyak faktor terkait lainnya untuk semua negara. Kumpulan data tersedia untuk umum untuk tujuan analisis data kesehatan. Kumpulan data yang terkait dengan harapan hidup, faktor kesehatan untuk 193 negara telah dikumpulkan dari situs web penyimpanan data WHO yang sama dan data ekonomi terkait dikumpulkan dari situs web Perserikatan Bangsa-Bangsa. Di antara semua kategori faktor yang berhubungan dengan kesehatan hanya faktor kritis yang dipilih yang lebih representatif. Telah diamati bahwa dalam 15 tahun terakhir, telah terjadi perkembangan besar di bidang kesehatan yang mengakibatkan peningkatan angka kematian manusia terutama di negara-negara berkembang dibandingkan dengan 30 tahun terakhir. File data individual telah digabungkan menjadi satu kumpulan data. Pada inspeksi visual awal data menunjukkan beberapa nilai yang hilang. Karena kumpulan data berasal dari WHO, kami tidak menemukan kesalahan yang jelas. Data yang hilang ditangani dalam perangkat lunak R dengan menggunakan perintah Missmap. Hasilnya menunjukkan bahwa sebagian besar data yang hilang adalah untuk populasi, Hepatitis B dan PDB. Data yang hilang berasal dari negara-negara yang kurang dikenal seperti Vanuatu, Tonga, Togo, Cabo Verde dll. Menemukan semua data untuk negara-negara ini sulit dan karenanya, diputuskan bahwa kami mengecualikan negara-negara ini dari kumpulan data model akhir. Semua variabel prediksi kemudian dibagi menjadi beberapa kategori besar: faktor terkait imunisasi, faktor kematian, faktor ekonomi dan faktor sosial.
#
#
# ## Semua data ini kami dapatkan dari website Kaggle
# ![Kaggle3.png](attachment:Kaggle3.png)

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # A. Pendahuluan
#
# ****

# %% [markdown]
# ## Import library yang akan digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize
import seaborn as sns
from matplotlib import cm
from collections import Counter

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Membaca Data

# %%
dfL = pd.read_csv("./life_expectancy.csv")

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # B. Deskripsi Data dan File
# ****

# %% [markdown]
# ## Deskripsi File

# %% [markdown]
# Life Expectancy [(sumber)](https://www.kaggle.com/kumarajarshi/life-expectancy-who)
# > Format: CSV
# >
# > Ukuran file: 333 kB
# >
# > Dimensi: 2938 baris x 22 kolom

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Dimensi Data

# %%
print(f"Dimensi data life expectancy: {dfL.shape[0]} baris x {dfL.shape[1]} kolom")
# Out:
# Dimensi data life expectancy: 2938 baris x 22 kolom

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # C. Karakteristik Data
# ****

# %% [markdown]
# ## Nama Kolom

# %%
dfL.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', 'BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', 'HIV/AIDS', 'GDP', 'Population', 'thinness  1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Rename Kolom

# %%
dfL.rename(columns = {"BMI " :"BMI", 
                      "Life expectancy ": "Life_expectancy",
                      "Adult Mortality":"Adult_mortality",
                      "infant deaths":"Infant_deaths",
                      "percentage expenditure":"Percentage_expenditure",
                      "Hepatitis B":"HepatitisB",
                      "Measles ":"Measles",
                      "under-five deaths ": "Under_five_deaths",
                      "Total expenditure":"Total_expenditure",
                      "Diphtheria ": "Diphtheria",
                      "thinness  1-19 years":"Thinness_1-19_years",
                      "thinness 5-9 years":"Thinness_5-9_years",
                      "HIV/AIDS":"HIV/AIDS",
                      "Income composition of resources":"Income_composition_of_resources"}, inplace = True)

# %% [markdown]
# ## Nama Kolom Setelah di-rename

# %%
dfL.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life_expectancy', 'Adult_mortality',
#        'Infant_deaths', 'Alcohol', 'Percentage_expenditure', 'HepatitisB',
#        'Measles', 'BMI', 'Under_five_deaths', 'Polio', 'Total_expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'Thinness_1-19_years',
#        'Thinness_5-9_years', 'Income_composition_of_resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Tipe data

# %%
dfL.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life_expectancy                    float64
# Adult_mortality                    float64
# Infant_deaths                        int64
# Alcohol                            float64
# Percentage_expenditure             float64
# HepatitisB                         float64
# Measles                              int64
# BMI                                float64
# Under_five_deaths                    int64
# Polio                              float64
# Total_expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# Thinness_1-19_years                float64
# Thinness_5-9_years                 float64
# Income_composition_of_resources    float64
# Schooling                          float64
# dtype: object

# %% [markdown]
# #### Penjelasan Kolom:
# 1. Country: Negara
# 2. Year: Tahun
# 3. Status: Negara berkembang atau maju (Developing/Developed)
# 4. Life_expectancy: Harapan hidup (dalam tahun)
# 5. Adult_Mortality: Kematian pada umur dewasa untuk kedua jenis kelamin (Probabilitas meninggal pada umur antara 15 sampai 60 per 1000 populasi)
# 6. Infant_deaths: Jumlah kematian bayi per 1000 populasi
# 7. Alcohol: Konsumsi alkohol per kapita (dalam liter alkohol murni)
# 8. Percentage_expenditure: Biaya pengeluaran dalam bidang kesehatan (dalam persentase dari bruto produk domestik per kapita)
# 9. Hepatitis B: Imunisasi Hepatitis B untuk anak umur 1 tahun (dalam persentase)
# 10. Measles: Jumlah laporan kasus campak per 1000 populasi
# 11. Under_five_deaths: Jumlah kematian di bawah 5 tahun per 1000 populasi
# 12. Polio: Imunisasi untuk anak umur 1 tahun (dalam persentase)
# 13. Total_expenditure: Pengeluaran total dalam bidang kesehatan dari total pengeluaran total pemerintah (dalam persentase)
# 14. Diphtheria: Imunisasi Diphteria tetanus toxoid and pertussis (DTP3) untuk anak umur 1 tahun (dalam persentase)
# 15. HIV/AIDS: Kematian per 1000 kelahiran dengan HIV/AIDS (0-4 tahun)
# 16. GDP: Gross Domestic per capita (dalam USD)
# 17. Population: Jumlah populasi sebuah negara
# 18. thinness_1-19 years: Tersebarnya kekurusan anak anak dan remaja umur 10 hingga 19 (dalam persentase)
# 19. thinness_5-9_years: Tersebarnya kekurusan anak anak umur 5 hingga 9 (dalam persentase)
# 20. Income_composition of resources: Indeks Pembangunan Manusia dalam aspek komposisi pendapatan dari sumber daya (berkisar dari 0 hingga 1)
# 21. Schooling: Jumlah tahun sekolah (dalam tahun)

# %% [markdown]
# #### Jenis Data:
# - Categorical-Nominal: Country
# - Categorical-Binary: Status
# - Quantitative-Discrete: Year, Adult Mortality, infant deaths, Hepatitis B, Measles, under-five deaths, Polio, Diphtheria, Population
# - Quantitative-Continues: Life expectancy, Alcohol, percentage expenditure, BMI, total expenditure, HIV/AIDS, GDP, thinness 1-19 years, thinness 5-9 years, Income composition of resources"

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # D. Data Cleaning
# ****

# %% [markdown]
# ### Jumlah data yang kosong untuk tiap kolom data life expectancy

# %%
print("\033[1m{:35}{:20}{:15}{:<15}\033[0m".format("Nama Kolom", "Jumlah Data Kosong", "Jumlah Data", "Persentase Kosong"))
for i in range(len(dfL.columns)):
    persentase = dfL[dfL.columns[i]].isna().sum()/len(dfL[dfL.columns[i]])*100
    Nama = dfL.columns[i].replace(" ", "")
    dK = dfL[dfL.columns[i]].isna().sum()
    jD = len(dfL[dfL.columns[i]])
    persentase = dK/jD*100
    print("{:<35}{:<20}{:<15}{:.2f}%".format(Nama, dK, jD, persentase))
# Out:
# Nama Kolom                         Jumlah Data Kosong  Jumlah Data    Persentase Kosong
# Country                            0                   2938           0.00%
# Year                               0                   2938           0.00%
# Status                             0                   2938           0.00%
# Life_expectancy                    10                  2938           0.34%
# Adult_mortality                    10                  2938           0.34%
# Infant_deaths                      0                   2938           0.00%
# Alcohol                            194                 2938           6.60%
# Percentage_expenditure             0                   2938           0.00%
# HepatitisB                         553                 2938           18.82%
# Measles                            0                   2938           0.00%
# BMI                                34                  2938           1.16%
# Under_five_deaths                  0                   2938           0.00%
# Polio                              19                  2938           0.65%
# Total_expenditure                  226                 2938           7.69%
# Diphtheria                         19                  2938           0.65%
# HIV/AIDS                           0                   2938           0.00%
# GDP                                448                 2938           15.25%
# Population                         652                 2938           22.19%
# Thinness_1-19_years                34                  2938           1.16%
# Thinness_5-9_years                 34                  2938           1.16%
# Income_composition_of_resources    167                 2938           5.68%
# Schooling                          163                 2938           5.55%

# %% [markdown]
# #### Data ini merupakan data gabungan dari beberapa data masing-masing negara. Ada aspek yang tidak dilaporkan beberapa negara seperti vaksinasi hepatitis B, GDP, dan Populasi. Data yang kosong ini berasal dari negara yang terpencil seperti Vanuatu, Tonga, Togo, dan Carbo Verde.
# #### Data yang kosong (berupa Null) ini diputuskan untuk diganti menjadi nilai mediannya.

# %%
# numerical untuk menyimpan dataframe yang berupa integer/float
numerical = pd.DataFrame().reindex_like(dfL)

for i in range(3, len(dfL.columns)):
    if(dfL[dfL.columns[i]].dtypes == "int64" or dfL[dfL.columns[i]].dtypes == "float64"):
        numerical[dfL.columns[i]] = dfL[dfL.columns[i]]

numerical = numerical.drop(["Country", "Year", "Status"], axis=1)
for i in range(len(numerical.columns)):
    numerical[numerical.columns[i]].fillna(numerical[numerical.columns[i]].median(), inplace=True)

    
for i in range(3, len(dfL.columns)):
    if(dfL[dfL.columns[i]].dtypes == "int64" or dfL[dfL.columns[i]].dtypes == "float64"):
        dfL[dfL.columns[i]] = numerical[dfL.columns[i]]

# %% [markdown]
# ### Jumlah data yang kosong setelah dilakukan pengisian

# %%
print("\033[1m{:35}{:20}{:15}{:<15}\033[0m".format("Nama Kolom", "Jumlah Data Kosong", "Jumlah Data", "Persentase Kosong"))
for i in range(len(dfL.columns)):
    persentase = dfL[dfL.columns[i]].isna().sum()/len(dfL[dfL.columns[i]])*100
    Nama = dfL.columns[i].replace(" ", "")
    dK = dfL[dfL.columns[i]].isna().sum()
    jD = len(dfL[dfL.columns[i]])
    persentase = dK/jD*100
    print("{:<35}{:<20}{:<15}{:.2f}%".format(Nama, dK, jD, persentase))
# Out:
# Nama Kolom                         Jumlah Data Kosong  Jumlah Data    Persentase Kosong
# Country                            0                   2938           0.00%
# Year                               0                   2938           0.00%
# Status                             0                   2938           0.00%
# Life_expectancy                    0                   2938           0.00%
# Adult_mortality                    0                   2938           0.00%
# Infant_deaths                      0                   2938           0.00%
# Alcohol                            0                   2938           0.00%
# Percentage_expenditure             0                   2938           0.00%
# HepatitisB                         0                   2938           0.00%
# Measles                            0                   2938           0.00%
# BMI                                0                   2938           0.00%
# Under_five_deaths                  0                   2938           0.00%
# Polio                              0                   2938           0.00%
# Total_expenditure                  0                   2938           0.00%
# Diphtheria                         0                   2938           0.00%
# HIV/AIDS                           0                   2938           0.00%
# GDP                                0                   2938           0.00%
# Population                         0                   2938           0.00%
# Thinness_1-19_years                0                   2938           0.00%
# Thinness_5-9_years                 0                   2938           0.00%
# Income_composition_of_resources    0                   2938           0.00%
# Schooling                          0                   2938           0.00%

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ### Menghapus Outliers (Data yang Berbeda Jauh dengan Lainnya)

# %% [markdown]
# #### Menggunakan Plot Kotak (Box Plot) Untuk Mencari Outliers

# %%
plt.figure(figsize=(20,30))

for i in range (0,len(numerical.columns)):
    plt.subplot(5,5,i+1)
    sns.boxplot(y=numerical[numerical.columns[i]], color="red")
    plt.title(numerical.columns[i], color="black")
    plt.ylabel("")
    plt.grid(True)
    plt.rcParams['axes.axisbelow'] = True  
plt.show()

# %% [markdown]
# #### Infant_deaths, Measles, Under_five_deaths, HIV/AIDS adalah data per 1000 populasi. Keempat data ini tidak mungkin melebihi 1000, sehingga data yang melebihi 1000 harus dihapus.
# #### Beberapa negara memiliki nilai GDP dan Expenditure_percentage yang melebihi 20.000%, sehingga perlu diolah lebih lanjut.
# #### Nilai BMI yang melebihi 35 sudah termasuk obesitas, namun dari boxplot, terlihat bahwa lebih dari setengah data BMI melebihi 35. Kolom ini tidak valid sehingga diputuskan untuk di-delete
# ![](BMI.jpeg)

# %% [markdown]
# #### Menghapus data Infant_deaths, Measles, Under_five_deaths, HIV/AIDS yang melebihi 1000

# %%
dfL = dfL[dfL["Infant_deaths"] <= 1000]
dfL = dfL[dfL["Measles"] <= 1000]
dfL = dfL[dfL["Under_five_deaths"] <= 1000]

# %% [markdown]
# #### Menghapus Kolom BMI

# %%
dfL.drop(["BMI"], axis=1, inplace=True, errors="ignore")

# %% [markdown]
# #### Menggunakan logaritma untuk mengubah data kolom "Percentage_expenditure", "Population", dan "GDP" menjadi logaritma dari nilainya karena perbandingan ukuran box dan data outliers yang jauh

# %%
old = np.seterr(invalid='ignore')

dfL["log_Percentage_expenditure"] = np.log(dfL["Percentage_expenditure"])
dfL["log_Population"] = np.log(dfL["Population"])
dfL["log_GDP"] = np.log(dfL["GDP"])
dfL = dfL.replace([np.inf, -np.inf], 0)
np.seterr(**old)
# Out:
# C:\Users\Carlios\anaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %% [markdown]
# #### Dikarenakan semua data mempunyai outliers yang cukup banyak, maka akan digunakan metode winsorization yaitu dengan mengubah nilai outliers menjadi nilai persentil yang terdekat

# %%
dfL['winz_Life_expectancy'] = winsorize(dfL['Life_expectancy'], (0.05,0))
dfL['winz_Adult_mortality'] = winsorize(dfL['Adult_mortality'], (0,0.04))
dfL['winz_Alcohol'] = winsorize(dfL['Alcohol'], (0.0,0.01))
dfL['winz_HepatitisB'] = winsorize(dfL['HepatitisB'], (0.20,0.0))
dfL['winz_Polio'] = winsorize(dfL['Polio'], (0.20,0.0))
dfL['winz_Total_expenditure'] = winsorize(dfL['Total_expenditure'], (0.0,0.02))
dfL['winz_Diphtheria'] = winsorize(dfL['Diphtheria'], (0.11,0.0))
dfL['winz_HIV/AIDS'] = winsorize(dfL['HIV/AIDS'], (0.0,0.21))
dfL['winz_Thinness_1-19_years'] = winsorize(dfL['Thinness_1-19_years'], (0.0,0.04))
dfL['winz_Thinness_5-9_years'] = winsorize(dfL['Thinness_5-9_years'], (0.0,0.04))
dfL['winz_Income_composition_of_resources'] = winsorize(dfL['Income_composition_of_resources'], (0.05,0.0))
dfL['winz_Schooling'] = winsorize(dfL['Schooling'], (0.03,0.01))

# %% [markdown]
# #### Perbandingan dimensi data sebelum dan setelah data cleaning

# %%
print(f"Dimensi data life expectancy sebelum data cleaning: {2938} baris x {22} kolom")
print(f"Dimensi data life expectancy setelah data cleaning: {dfL.shape[0]} baris x {dfL.shape[1]} kolom")
# Out:
# Dimensi data life expectancy sebelum data cleaning: 2938 baris x 22 kolom
# Dimensi data life expectancy setelah data cleaning: 2413 baris x 36 kolom

# %% [markdown]
# #### Box plot setelah dilakukan data cleaning

# %%
plt.figure(figsize=(20,30))
numerical_winsor = pd.DataFrame().reindex_like(dfL)

for i in range(3, len(dfL.columns)):
    if(dfL[dfL.columns[i]].dtypes == "int64" or dfL[dfL.columns[i]].dtypes == "float64"):
        numerical_winsor[dfL.columns[i]] = dfL[dfL.columns[i]]

numerical_winsor = numerical_winsor.drop(["Country", "Year", "Status", "Percentage_expenditure", "Population","GDP", "Life_expectancy", "Adult_mortality", "Alcohol", "HepatitisB", "Polio", "Total_expenditure", "Diphtheria", "HIV/AIDS", "Thinness_1-19_years", "Thinness_5-9_years", "Income_composition_of_resources", "Schooling", ], axis=1)
for i in range (0, len(numerical_winsor.columns)):
    plt.subplot(5,4,i+1)
    sns.boxplot(y=numerical_winsor[numerical_winsor.columns[i]])
    plt.title(numerical_winsor.columns[i])
    plt.ylabel("")
    plt.grid(True)
    plt.rcParams['axes.axisbelow'] = True
plt.show()

# %%
dfL_Clean = dfL[['Year', 'Country', 'Status','winz_Life_expectancy','winz_Adult_mortality','Infant_deaths','winz_Alcohol',
            'log_Percentage_expenditure','winz_HepatitisB','Measles','Under_five_deaths','winz_Polio',
            'winz_Total_expenditure','winz_Diphtheria','winz_HIV/AIDS','log_GDP','log_Population',
            'winz_Thinness_1-19_years','winz_Thinness_5-9_years','winz_Income_composition_of_resources',
            'winz_Schooling']]

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # E. Statistik
# ****

# %% [markdown]
# ## Sampel Data

# %%
dfL_Clean.head(5)
# Out:
#     Year      Country      Status  winz_Life_expectancy  winz_Adult_mortality  \
# 1   2014  Afghanistan  Developing                 59.90                271.00
# 2   2013  Afghanistan  Developing                 59.90                268.00
# 11  2004  Afghanistan  Developing                 57.00                293.00
# 12  2003  Afghanistan  Developing                 56.70                295.00
# 16  2015      Albania  Developing                 77.80                 74.00
#
#     Infant_deaths  winz_Alcohol  log_Percentage_expenditure  winz_HepatitisB  \
# 1              64          0.01                        4.30            81.00
# 2              66          0.01                        4.29            81.00
# 11             87          0.02                        2.73            81.00
# 12             87          0.01                        2.41            81.00
# 16              0          4.60                        5.90            99.00
#
#     Measles  Under_five_deaths  winz_Polio  winz_Total_expenditure  \
# 1       492                 86       79.00                    8.18
# 2       430                 89       79.00                    8.13
# 11      466                120       79.00                    8.79
# 12      798                122       79.00                    8.82
# 16        0                  0       99.00                    6.00
#
#     winz_Diphtheria  winz_HIV/AIDS  log_GDP  log_Population  \
# 1             65.00           0.10     6.42           12.70
# 2             65.00           0.10     6.45           17.27
# 11            65.00           0.10     5.39           17.00
# 12            65.00           0.10     5.29           14.68
# 16            99.00           0.10     8.28           10.27
#
#     winz_Thinness_1-19_years  winz_Thinness_5-9_years  \
# 1                      12.00                    12.10
# 2                      12.00                    12.10
# 11                     12.00                    12.10
# 12                     12.00                    12.10
# 16                      1.20                     1.30
#
#     winz_Income_composition_of_resources  winz_Schooling
# 1                                   0.48           10.00
# 2                                   0.47            9.90
# 11                                  0.38            6.80
# 12                                  0.37            6.50
# 16                                  0.76           14.20

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Statistik

# %%
pd.set_option("max_columns", None)
pd.options.display.float_format = "{:,.2f}".format
dfL_Clean.describe()
# Out:
#           Year  winz_Life_expectancy  winz_Adult_mortality  Infant_deaths  \
# count 2,413.00              2,413.00              2,413.00       2,413.00
# mean  2,007.80                 70.71                151.04          10.34
# std       4.52                  8.47                106.26          24.40
# min   2,000.00                 52.60                  1.00           0.00
# 25%   2,004.00                 65.50                 72.00           0.00
# 50%   2,008.00                 72.90                136.00           2.00
# 75%   2,012.00                 76.30                215.00          10.00
# max   2,015.00                 89.00                412.00         549.00
#
#        winz_Alcohol  log_Percentage_expenditure  winz_HepatitisB  Measles  \
# count      2,413.00                    2,413.00         2,413.00 2,413.00
# mean           4.80                        4.13            90.90    88.98
# std            3.92                        2.81             6.30   186.94
# min            0.01                       -2.23            81.00     0.00
# 25%            1.32                        1.79            85.00     0.00
# 50%            3.75                        4.50            92.00     4.00
# 75%            7.70                        6.27            96.00    66.00
# max           13.59                        9.88            99.00   999.00
#
#        Under_five_deaths  winz_Polio  winz_Total_expenditure  winz_Diphtheria  \
# count           2,413.00    2,413.00                2,413.00         2,413.00
# mean               14.40       90.91                    6.04            88.82
# std                35.42        7.45                    2.31            11.15
# min                 0.00       79.00                    0.37            65.00
# 25%                 0.00       84.00                    4.59            84.00
# 50%                 2.00       94.00                    5.76            94.00
# 75%                12.00       97.00                    7.50            97.00
# max               879.00       99.00                   11.70            99.00
#
#        winz_HIV/AIDS  log_GDP  log_Population  winz_Thinness_1-19_years  \
# count       2,413.00 2,413.00        2,413.00                  2,413.00
# mean            0.29     7.63           13.73                      4.03
# std             0.29     1.71            2.27                      3.20
# min             0.10     1.73            3.53                      0.10
# 25%             0.10     6.60           12.70                      1.50
# 50%             0.10     7.48           14.14                      3.00
# 75%             0.40     8.65           15.07                      6.40
# max             0.80    11.69           19.11                     12.00
#
#        winz_Thinness_5-9_years  winz_Income_composition_of_resources  \
# count                 2,413.00                              2,413.00
# mean                      4.03                                  0.66
# std                       3.22                                  0.17
# min                       0.10                                  0.29
# 25%                       1.40                                  0.55
# 50%                       3.10                                  0.69
# 75%                       6.30                                  0.79
# max                      12.10                                  0.95
#
#        winz_Schooling
# count        2,413.00
# mean            12.47
# std              2.93
# min              5.30
# 25%             10.70
# 50%             12.50
# 75%             14.40
# max             19.10

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # F. Visualisasi
# ****

# %% [markdown]
# ## Histogram

# %%
plt.figure(figsize=(20,20))
for i in range(len(numerical_winsor.columns)):
    plt.subplot(5,6,i+1)
    plt.hist(numerical_winsor[numerical_winsor.columns[i]], edgecolor="Black")
    plt.title(numerical_winsor.columns[i], color="black")
    plt.ylabel("")
    plt.grid(True)
    plt.rcParams['axes.axisbelow'] = True
plt.show()

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# ## Grafik

# %%
plt.rcParams["text.color"] = "white"
cnewfont = {"fontname":"Calibri"}
plt.rcParams["font.size"] = 24
plt.figure(facecolor="black")
ax = plt.axes()
ax.set_facecolor("black")
dfL_status = dfL_Clean.groupby("Status").mean().sort_values("winz_Life_expectancy", ascending=True)
dfL_status["winz_Life_expectancy"].plot(figsize=(15,10),kind="bar", rot=0, color="paleturquoise", fontsize=12)
plt.xlabel("Status", **cnewfont, color="white")
plt.ylabel("Harapan Hidup Rata-Rata", **cnewfont, color="white")
plt.xticks(color="white", size=20)
plt.yticks(np.arange(0,90,step=10),color="white", size=20)
plt.title("Nilai Harapan Hidup Berdasarkan Status Sebuah Negara", **cnewfont)
plt.grid(True, axis="y", color="lightslategrey", which="major")
plt.plot([-20, 20], [0,0], color="lightslategrey")
plt.show()

# %% [markdown]
# ![](Blue.png)

# %%
plt.rcParams["font.size"] = 24
plt.rcParams["text.color"] = "white"
plt.figure(facecolor='black')
ax = plt.axes()
ax.set_facecolor("black")
dfL_status_year = dfL_Clean.groupby(["Status", "Year"])["winz_Life_expectancy"].mean()
developed = dfL_status_year["Developed"]
developing = dfL_status_year["Developing"]
developed.plot(figsize=(15,10),label="Maju", color="aqua")
developing.plot(label="Berkembang", color="hotpink")

legend = plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
frame = legend.get_frame()
frame.set_facecolor('black')
frame.set_edgecolor('black')
plt.xticks( np.arange(2000,2016, step=5), color="white")
plt.yticks( color="white")
ax = plt.gca()
ax.set_xlim(2000,2015)
plt.xlabel("Tahun", color="white")
plt.ylabel("Harapan Hidup", color="white")

plt.title("Harapan Hidup untuk Negara Maju dan Berkembang\nDalam Kurun Waktu 2000-2015")
plt.grid(True, color="lightslategrey")

# %% [markdown]
# ![](Purple.png)

# %% [markdown]
# # G. Korelasi
# ****

# %% [markdown]
# ## Heatmap

# %%
plt.rcParams["font.size"] = 10
plt.figure(figsize=(15,10))
sns.heatmap(dfL_Clean.corr(), annot=True, linewidths = 4)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# #### Berdasarkan heatmap yang telah digambarkan sebelumnya, dapat disimpulkan:

# %% [markdown]
# 1. Moratlitas orang dewasa memiliki korelasi negatif dengan edukasi dan Indeks Pembangunan Manusia

# %%
# Korelasi atnara winz_Adult_mortality dengan winz_Schooling
plt.rcParams["font.size"] = 12
plt.figure(figsize=(20,6), facecolor="black")
x=dfL_Clean["winz_Adult_mortality"]
y=dfL_Clean["winz_Schooling"]

ax = plt.subplot(1,2,1)
ax.spines["bottom"].set_color("white")
ax.spines["left"].set_color("white")
ax.set_facecolor("black")

plt.scatter(x, y, color="#DA627D", s=15)
plt.xticks(color="white")
plt.yticks(color="white")

m,b = np.polyfit(x, y, 1)
plt.subplot(1,2,1)
plt.plot(x, m*x+b, color="white")
plt.xlabel("Mortalitas Orang Dewasa (per 1000 populasi)", color="white")
plt.ylabel("Jumlah Tahun Sekolah", color="white")
plt.title("Korelasi Mortalitas Orang Dewasa\ndengan Pendidikan")
print("Korelasi antara mortalitas orang dewasa dengan pendidikan =", x.corr(y))




# Korelasi winz_Adult_mortality dengan winz_Income_composition_of_resources
x=dfL_Clean["winz_Adult_mortality"]
y=dfL_Clean["winz_Income_composition_of_resources"]

ax =plt.subplot(1,2,2)
ax.spines["bottom"].set_color("white")
ax.spines["left"].set_color("white")
ax.set_facecolor("black")

plt.scatter(x,y, color="#F9DBBD", s=15)
plt.xticks(color="white")
plt.yticks(color="white")

m,b = np.polyfit(x, y, 1)
plt.subplot(1,2,2)
plt.plot(x, m*x+b, color="white")
plt.xlabel("Mortalitas Orang Dewasa (per 1000 populasi)", color="white")
plt.ylabel("IPM", color="white")
plt.title("Korelasi Mortalitas Orang Dewasa dengan\nIndeks Pembangunan Manusia(IPM)")
print("Korelasi mortalitas orang dewasa denganIndeks Pembangunan Manusia(IPM) =", x.corr(y))
# Out:
# Korelasi antara mortalitas orang dewasa dengan pendidikan = -0.5011059887774686
# Korelasi mortalitas orang dewasa denganIndeks Pembangunan Manusia(IPM) = -0.5417612269973405

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# 2. Korelasi tinggi antara kematian bayi dengan kematian di bawah 5 tahun.

# %%
plt.rcParams["font.size"] = 18
plt.figure(figsize=(15,10), facecolor="black")

x=dfL_Clean["Infant_deaths"]
y=dfL_Clean["Under_five_deaths"]
ax = plt.axes()
ax.spines["left"].set_color("white")
ax.spines["bottom"].set_color("white")
ax.set(facecolor="black")
plt.scatter(x, y, color="#77B28C", s=100)
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("Kematian Bayi (per 1000 populasi)", color="white")
plt.ylabel("Kematian Umur di Bawah 5 Tahun (per 1000 populasi)", color="white")
m,b = np.polyfit(x, y, 1)
plt.title("Korelasi Antara Kematian Bayi dengan Kematian di Bawah 5 Tahun")
plt.plot(x, m*x+b, color="white")
print("Nilai korelasi antara kematian bayi dengan kematian di bawah umur 5 tahun = ", x.corr(y))
# Out:
# Nilai korelasi antara kematian bayi dengan kematian di bawah umur 5 tahun =  0.9905128215000544

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# 3. Persentase anggaran pengeluaran untuk kesehatan berkorelasi positif dengan edukasi, GDP, IPM, dan harapan hidup

# %%
plt.rcParams["font.size"] = 12
plt.figure(figsize=(15,10), facecolor="black")
ax = plt.subplot(2,2,1)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")
x=dfL_Clean["log_Percentage_expenditure"]
y=dfL_Clean["winz_Schooling"]
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("", color="white")
plt.ylabel("Jumlah Tahun Sekolah)", color="white")
plt.title("Korelasi Persentase Biaya Pengeluaran\ndalam Bidang Kesehatan dengan Edukasi")
plt.scatter(x,y, color="#B3B3F1")
m,b = np.polyfit(x, y, 1)
plt.plot(x, 1.2*x+6, color="white")
print("Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan edukasi = ", x.corr(y))


ax = plt.subplot(2,2,2)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")
x=dfL_Clean["log_Percentage_expenditure"]
y=dfL_Clean["log_GDP"]
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("", color="white")
plt.ylabel("GDP (dalam USD)", color="white")
plt.title("Korelasi Persentase Biaya Pengeluaran\ndalam Bidang Kesehatan dengan GDP")
plt.scatter(x,y, color="#F17195")
m,b = np.polyfit(x, y, 1)
plt.plot(x, 0.8*x+4, color="white")
print("Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan GDP = ", x.corr(y))


ax = plt.subplot(2,2,3)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")
x=dfL_Clean["log_Percentage_expenditure"]
y=dfL_Clean["winz_Life_expectancy"]
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("", color="white")
plt.ylabel("Harapan Hidup (dalam tahun)", color="white")
plt.title("Korelasi Persentase Biaya Pengeluaran\ndalam Bidang Kesehatan dengan Harapan Hidup")
plt.scatter(x,y, color="#D11149")
m,b = np.polyfit(x, y, 1)
plt.plot(x, 3.5*x+55, color="white")
print("Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan harapan hidup = ", x.corr(y))


ax = plt.subplot(2,2,4)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")
x=dfL_Clean["log_Percentage_expenditure"]
y=dfL_Clean["winz_Income_composition_of_resources"]
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("", color="white")
plt.ylabel("IPM", color="white")
plt.title("Korelasi Persentase Biaya Pengeluaran\ndalam Bidang Kesehatan dengan IPM")
plt.scatter(x,y, color="#6610F2")
m,b = np.polyfit(x, y, 1)
plt.plot(x, 0.07*x+0.3, color="white")
print("Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan IPM = ", x.corr(y))
# Out:
# Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan edukasi =  0.41559192826835306
# Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan GDP =  0.6160245912319404
# Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan harapan hidup =  0.37862817697862255
# Nilai korelasi antara persentase biaya pengeluaran dalam bidang kesehatan dengan IPM =  0.4079302726045927

# %% [markdown]
# ![](Blue.png)

# %% [markdown]
# 4. Hepatitis B berkorelasi positif yang kuat dengan polio dan difteri

# %%
plt.rcParams["font.size"] = 12
plt.figure(figsize=(15,5), facecolor="black")
x_vals = np.array(dfL_Clean["winz_HepatitisB"])
y_vals = np.array(dfL_Clean["winz_Polio"])
x = dfL_Clean["winz_HepatitisB"]
y = dfL_Clean["winz_Polio"]

ax = plt.subplot(1,2,1)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")

combos = list(zip(x_vals, y_vals))
weight_counter = Counter(combos)
weights = [(weight_counter[(x_vals[i], y_vals[i])])**1.7/30 for i, _ in enumerate(x_vals)]
plt.scatter(x,y,s=weights, c="#EFCA08")
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("Hepatitis B", color="white")
plt.ylabel("Polio", color="white")
plt.title("Korelasi Imunisasi Hepatitis B dengan Polio\nuntuk Anak di Bawah 5 Tahun", color="white")

m,b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b, color="white")
print("Nilai korelasi antara imunisasi hepatitis B dengan imunisasi polio = ", x.corr(y))



x_vals = np.array(dfL_Clean["winz_HepatitisB"])
y_vals = np.array(dfL_Clean["winz_Diphtheria"])
x = dfL_Clean["winz_HepatitisB"]
y = dfL_Clean["winz_Diphtheria"]

ax = plt.subplot(1,2,2)
ax.set(facecolor="black")
ax.spines["left"].set(color="white")
ax.spines["bottom"].set(color="white")

combos = list(zip(x_vals, y_vals))
weight_counter = Counter(combos)
weights = [weight_counter[(x_vals[i], y_vals[i])]**1.7/30 for i, _ in enumerate(x_vals)]
plt.scatter(x,y,s=weights, color="#F08700")
plt.xticks(color="white")
plt.yticks(color="white")
plt.xlabel("Hepatitis B", color="white")
plt.ylabel("Difteri", color="white")
plt.title("Korelasi Imunisasi Hepatitis B dengan Difteri\nuntuk Anak di Bawah 5 Tahun", color="white")

m,b = np.polyfit(x, y, 1)
plt.plot(x, m*x+b, color="white")
print("Nilai korelasi antara imunisasi hepatitis B dengan imunisasi difteri = ", x.corr(y))
# Out:
# Nilai korelasi antara imunisasi hepatitis B dengan imunisasi polio =  0.7148671653100224
# Nilai korelasi antara imunisasi hepatitis B dengan imunisasi difteri =  0.6518395534787221

# %% [markdown]
# ![](Purple.png)
